# %% [markdown]
# ## Learning Outcomes
# - Exploratory data analysis & preparing the data for model building.
# - Machine Learning - Supervised Learning Classification
#   - Logistic Regression
#   - Naive bayes Classifier
#   - KNN Classifier
#   - Decision Tree Classifier
#   - Random Forest Classifier
#   - Ensemble methods
# - Training and making predictions using different classification models.
# - Model evaluation

# %% [markdown]
# ## Objective:
# - The Classification goal is to predict “heart disease” in a person with regards to different factors given.
#
# ## Context:
# - Heart disease is one of the leading causes of death for people of most races in the US. At least 1 of 3 key risk factors for heart disease: high blood pressure, high cholesterol, and smoking.
# - Detecting and preventing the factors that have the greatest impact on heart disease is very important in healthcare. Machine learning methods may detect "patterns" from the data and can predict whether a patient is suffering from any heart disease or not..
#
# ## Dataset Information
#
# #### Source: https://www.kaggle.com/datasets/kamilpytlak/personal-key-indicators-of-heart-disease?datasetId=1936563&sortBy=voteCount
# Originally, the dataset come from the CDC and is a major part of the Behavioral Risk Factor Surveillance System (BRFSS), which conducts annual telephone surveys to gather data on the health status of U.S. residents.
#
# This dataset consists of eighteen columns
# - HeartDisease: Respondents that have ever reported having coronary heart disease (CHD) or myocardial infarction (MI)
# - BMI: Body Mass Index (BMI)
# - Smoking: smoked at least 100 cigarettes in your entire life
# - AlcoholDrinking: Heavy drinkers (adult men having more than 14 drinks per week and adult women having more than 7 drinks per week
# - Stroke:Ever had a stroke?
# - PhysicalHealth: physical health, which includes physical illness and injury
# - MentalHealth: for how many days during the past 30 days was your mental health not good?
# - DiffWalking: Do you have serious difficulty walking or climbing stairs?
# - Sex: male or female?
# - AgeCategory: Fourteen-level age category
# - Race: Imputed race/ethnicity value
# - Diabetic: diabetes?
# - PhysicalActivity: Adults who reported doing physical activity or exercise during the past 30 days other than their regular job
# - GenHealth: Would you say that in general your health is good, fine or excellent?
# - SleepTime: On average, how many hours of sleep do you get in a 24-hour period?
# - Asthma: you had asthma?
# - KidneyDisease: Not including kidney stones, bladder infection or incontinence, were you ever told you had kidney disease?
# - SkinCancer: Ever had skin cancer?

# %% [markdown]
# ### 1. Importing Libraries

# %%
import pandas as pd

# %% [markdown]
# ### 2. Load the dataset and display a sample of five rows of the data frame.

# %%
import pandas as pd
file_path = 'C:/Users/hp/Downloads/heart_2020_cleaned.csv'

# Load the dataset
df = pd.read_csv(file_path)

# Display a sample of five rows
print(df.head())
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0           No  16.60     Yes              No     No             3.0
# 1           No  20.34      No              No    Yes             0.0
# 2           No  26.58     Yes              No     No            20.0
# 3           No  24.21      No              No     No             0.0
# 4           No  23.71      No              No     No            28.0
#
#    MentalHealth DiffWalking     Sex  AgeCategory   Race Diabetic  \
# 0          30.0          No  Female        55-59  White      Yes
# 1           0.0          No  Female  80 or older  White       No
# 2          30.0          No    Male        65-69  White      Yes
# 3           0.0          No  Female        75-79  White       No
# 4           0.0         Yes  Female        40-44  White       No
#
#   PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 0              Yes  Very good        5.0    Yes            No        Yes
# ...

# %% [markdown]
# ### 3. Check the shape of the data (number of rows and columns). Check the general information about the dataframe using the .info() method.

# %%
import pandas as pd
file_path = r'C:\Users\hp\Downloads\heart_2020_cleaned.csv'

# Load the dataset
df = pd.read_csv(file_path)

# Check the shape of the data
print("\nShape of the data (rows, columns):")
print(df.shape)

# Check general information about the dataframe
print("\nGeneral information about the dataframe:")
print(df.info())
# Out:
# Shape of the data (rows, columns):
# (319795, 18)
#
# General information about the dataframe:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319795 entries, 0 to 319794
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   HeartDisease      319795 non-null  object
#  1   BMI               319795 non-null  float64
#  2   Smoking           319795 non-null  object
#  3   AlcoholDrinking   319795 non-null  object
#  4   Stroke            319795 non-null  object
#  5   PhysicalHealth    319795 non-null  float64
#  6   MentalHealth      319795 non-null  float64
#  7   DiffWalking       319795 non-null  object
#  8   Sex               319795 non-null  object
#  9   AgeCategory       319795 non-null  object
#  10  Race              319795 non-null  object
#  11  Diabetic          319795 non-null  object
#  12  PhysicalActivity  319795 non-null  object
#  13  GenHealth         319795 non-null  object
# ...

# %% [markdown]
# ### 4. Check the statistical summary of the dataset and write your inferences.

# %%
import pandas as pd
file_path = r'C:\Users\hp\Downloads\heart_2020_cleaned.csv'

# Load the dataset
df = pd.read_csv(file_path)
# Check the statistical summary of the dataset
print("\nStatistical summary of the dataset:")
print(df.describe())
# Out:
# Statistical summary of the dataset:
#                  BMI  PhysicalHealth   MentalHealth      SleepTime
# count  319795.000000    319795.00000  319795.000000  319795.000000
# mean       28.325399         3.37171       3.898366       7.097075
# std         6.356100         7.95085       7.955235       1.436007
# min        12.020000         0.00000       0.000000       1.000000
# 25%        24.030000         0.00000       0.000000       6.000000
# 50%        27.340000         0.00000       0.000000       7.000000
# 75%        31.420000         2.00000       3.000000       8.000000
# max        94.850000        30.00000      30.000000      24.000000

# %% [markdown]
# ### 5. Check the percentage of missing values in each column of the data frame. Drop the missing values if there are any.

# %%
import pandas as pd

file_path = r'C:\Users\hp\Downloads\heart_2020_cleaned.csv'

# Load the dataset
df = pd.read_csv(file_path)

# Calculate the percentage of missing values in each column
missing_percentage = df.isnull().mean() * 100
print("\nPercentage of missing values in each column:")
print(missing_percentage)

# Drop rows with missing values
df_cleaned = df.dropna()

# Check the shape of the data after dropping missing values
print("\nShape of the data after dropping missing values (rows, columns):")
print(df_cleaned.shape)
# Out:
# Percentage of missing values in each column:
# HeartDisease        0.0
# BMI                 0.0
# Smoking             0.0
# AlcoholDrinking     0.0
# Stroke              0.0
# PhysicalHealth      0.0
# MentalHealth        0.0
# DiffWalking         0.0
# Sex                 0.0
# AgeCategory         0.0
# Race                0.0
# Diabetic            0.0
# PhysicalActivity    0.0
# GenHealth           0.0
# SleepTime           0.0
# Asthma              0.0
# KidneyDisease       0.0
# SkinCancer          0.0
# dtype: float64
#
# Shape of the data after dropping missing values (rows, columns):
# (319795, 18)

# %% [markdown]
# ### 6. Check if there are any duplicate rows. If any drop them and check the shape of the dataframe after dropping duplicates.

# %%
import pandas as pd

# Correcting the file path
file_path = r'C:\Users\hp\Downloads\heart_2020_cleaned.csv'

# Load the dataset
df = pd.read_csv(file_path)

# Drop rows with missing values
df_cleaned = df.dropna()

# Check the shape of the data after dropping missing values
print("\nShape of the data after dropping missing values (rows, columns):")
print(df_cleaned.shape)

# Check for duplicate rows
duplicates = df_cleaned.duplicated().sum()
print("\nNumber of duplicate rows:")
print(duplicates)

# Drop duplicate rows
df_cleaned = df_cleaned.drop_duplicates()

# Check the shape of the data after dropping duplicates
print("\nShape of the data after dropping duplicates (rows, columns):")
print(df_cleaned.shape)
# Out:
# Shape of the data after dropping missing values (rows, columns):
# (319795, 18)
#
# Number of duplicate rows:
# 18078
#
# Shape of the data after dropping duplicates (rows, columns):
# (301717, 18)

# %% [markdown]
# ### 7. Check the distribution of the target variable (i.e. 'HeartDisease') and write your observations.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Correcting the file path
file_path = r'C:\Users\hp\Downloads\heart_2020_cleaned.csv'

# Load the dataset
df = pd.read_csv(file_path)

# Check the distribution of the target variable 'HeartDisease'
heart_disease_counts = df['HeartDisease'].value_counts()
print("\nDistribution of the target variable 'HeartDisease':")
print(heart_disease_counts)

# Visualize the distribution of the target variable 'HeartDisease'
plt.figure(figsize=(8, 6))
sns.countplot(x='HeartDisease', data=df)
plt.title('Distribution of HeartDisease')
plt.xlabel('HeartDisease')
plt.ylabel('Count')
plt.show()
# Out:
# Distribution of the target variable 'HeartDisease':
# HeartDisease
# No     292422
# Yes     27373
# Name: count, dtype: int64

# %% [markdown]
# ### 8. Visualize the distribution of the target column 'Heart disease' with respect to various categorical features and write your observations.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Correcting the file path
file_path = r'C:\Users\hp\Downloads\heart_2020_cleaned.csv'

# Load the dataset
df = pd.read_csv(file_path)

# Define categorical features to analyze
categorical_features = ['Sex', 'Smoking', 'AlcoholDrinking', 'Stroke', 'PhysicalActivity']

# Set up the matplotlib figure
plt.figure(figsize=(20, 15))

# Loop through the categorical features and create bar plots
for i, feature in enumerate(categorical_features, 1):
    plt.subplot(3, 2, i)
    sns.countplot(x=feature, hue='HeartDisease', data=df_cleaned)
    plt.title(f'Heart Disease Distribution by {feature}')
    plt.xlabel(feature)
    plt.ylabel('Count')

# Adjust layout
plt.tight_layout()
plt.show()
'''
Observations from the Visualizations:
Sex:

The distribution of heart disease among different sexes can show if there is a significant difference in heart disease prevalence between males and females.
Smoking:

The bar plot can reveal the correlation between smoking status and heart disease, indicating if smokers have a higher prevalence of heart disease compared to non-smokers.
Alcohol Drinking:

This plot shows whether alcohol consumption is related to heart disease. A higher prevalence in drinkers would suggest a correlation.
Stroke:

By examining this feature, we can see if individuals with a history of stroke have a higher incidence of heart disease compared to those without a stroke.
Physical Activity:

This plot reveals the relationship between physical activity levels and heart disease. Typically, lower physical activity might be associated with higher heart disease prevalence.
These visualizations can help identify important features that are associated with heart disease and provide insights for further analysis or model building. If certain features show a strong correlation with heart disease,
 they might be important predictors for a predictive model.
'''
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 20
#      18 for i, feature in enumerate(categorical_features, 1):
#      19     plt.subplot(3, 2, i)
# ---> 20     sns.countplot(x=feature, hue='HeartDisease', data=df_cleaned)
#      21     plt.title(f'Heart Disease Distribution by {feature}')
#      22     plt.xlabel(feature)
#
# NameError: name 'df_cleaned' is not defined

# %% [markdown]
# ### 9. Check the unique categories in the column 'Diabetic'. Replace 'Yes (during pregnancy)' as 'Yes' and 'No, borderline diabetes' as 'No'.

# %%
import pandas as pd

# Correcting the file path
file_path = r'C:\Users\hp\Downloads\heart_2020_cleaned.csv'

# Load the dataset
df = pd.read_csv(file_path)

# Display unique categories in the 'Diabetic' column
print("Unique categories in the 'Diabetic' column before replacement:")
print(df['Diabetic'].unique())

# Replace specific categories
df['Diabetic'] = df['Diabetic'].replace({
    'Yes (during pregnancy)': 'Yes',
    'No, borderline diabetes': 'No'
})

# Display unique categories in the 'Diabetic' column after replacement
print("\nUnique categories in the 'Diabetic' column after replacement:")
print(df['Diabetic'].unique())
# Out:
# Unique categories in the 'Diabetic' column before replacement:
# ['Yes' 'No' 'No, borderline diabetes' 'Yes (during pregnancy)']
#
# Unique categories in the 'Diabetic' column after replacement:
# ['Yes' 'No']

# %% [markdown]
# ### 10. For the target column 'HeartDiease', Replace 'No' as 0 and 'Yes' as 1.

# %%
import pandas as pd

file_path = r'C:\Users\hp\Downloads\heart_2020_cleaned.csv'

# Load the dataset
df = pd.read_csv(file_path)

# Display unique categories in the 'Diabetic' column before replacement
print("Unique categories in the 'Diabetic' column before replacement:")
print(df['Diabetic'].unique())

# Replace specific categories in 'Diabetic' column
df['Diabetic'] = df['Diabetic'].replace({
    'Yes (during pregnancy)': 'Yes',
    'No, borderline diabetes': 'No'
})

# Display unique categories in the 'Diabetic' column after replacement
print("\nUnique categories in the 'Diabetic' column after replacement:")
print(df['Diabetic'].unique())

# Replace 'No' with 0 and 'Yes' with 1 in the 'HeartDisease' column
df['HeartDisease'] = df['HeartDisease'].replace({'No': 0, 'Yes': 1})

# Display unique values in the 'HeartDisease' column to verify changes
print("\nUnique values in the 'HeartDisease' column after replacement:")
print(df['HeartDisease'].unique())
# Out:
# Unique categories in the 'Diabetic' column before replacement:
# ['Yes' 'No' 'No, borderline diabetes' 'Yes (during pregnancy)']
#
# Unique categories in the 'Diabetic' column after replacement:
# ['Yes' 'No']
#
# Unique values in the 'HeartDisease' column after replacement:
# [0 1]
# C:\Users\hp\AppData\Local\Temp\ipykernel_23528\2431817119.py:24: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['HeartDisease'] = df['HeartDisease'].replace({'No': 0, 'Yes': 1})

# %% [markdown]
# ### 11. Label Encode the columns "AgeCategory", "Race", and "GenHealth". Encode the rest of the columns using dummy encoding approach.

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
file_path = r'C:\Users\hp\Downloads\heart_2020_cleaned.csv'

# Load the dataset
df = pd.read_csv(file_path)

# Define columns for label encoding and dummy encoding
columns_to_label_encode = ['AgeCategory', 'Race', 'GenHealth']
columns_to_dummy_encode = df.columns.difference(columns_to_label_encode + ['HeartDisease'])

# Label encode columns 'AgeCategory', 'Race', 'GenHealth'
label_encoder = LabelEncoder()
for col in columns_to_label_encode:
    df[col] = label_encoder.fit_transform(df[col])

# Dummy encode remaining columns
df = pd.get_dummies(df, columns=columns_to_dummy_encode)

# Display the encoded dataframe
print("Encoded DataFrame:")
print(df.head())
# Out:
# Encoded DataFrame:
#   HeartDisease  AgeCategory  Race  GenHealth  AlcoholDrinking_No  \
# 0           No            7     5          4                True
# 1           No           12     5          4                True
# 2           No            9     5          1                True
# 3           No           11     5          2                True
# 4           No            4     5          4                True
#
#    AlcoholDrinking_Yes  Asthma_No  Asthma_Yes  BMI_12.02  BMI_12.08  ...  \
# 0                False      False        True      False      False  ...
# 1                False       True       False      False      False  ...
# 2                False      False        True      False      False  ...
# 3                False       True       False      False      False  ...
# 4                False       True       False      False      False  ...
#
#    SleepTime_19.0  SleepTime_20.0  SleepTime_21.0  SleepTime_22.0  \
# ...

# %% [markdown]
# ### 12. Store the target column (i.e.'HeartDisease') in the y variable and the rest of the columns in the X variable.

# %%
import pandas as pd
file_path = r'C:\Users\hp\Downloads\heart_2020_cleaned.csv'

# Load the dataset
df = pd.read_csv(file_path)

# Define the target variable (y) and features (X)
y = df['HeartDisease']
X = df.drop(columns=['HeartDisease'])

# Display shapes of X and y
print(f"Shape of X: {X.shape}")
print(f"Shape of y: {y.shape}")

# Display first few rows of X and y
print("\nFirst few rows of X:")
print(X.head())

print("\nValues in y:")
print(y.value_counts())
# Out:
# Shape of X: (319795, 17)
# Shape of y: (319795,)
#
# First few rows of X:
#      BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  MentalHealth  \
# 0  16.60     Yes              No     No             3.0          30.0
# 1  20.34      No              No    Yes             0.0           0.0
# 2  26.58     Yes              No     No            20.0          30.0
# 3  24.21      No              No     No             0.0           0.0
# 4  23.71      No              No     No            28.0           0.0
#
#   DiffWalking     Sex  AgeCategory   Race Diabetic PhysicalActivity  \
# 0          No  Female        55-59  White      Yes              Yes
# 1          No  Female  80 or older  White       No              Yes
# 2          No    Male        65-69  White      Yes              Yes
# 3          No  Female        75-79  White       No               No
# 4         Yes  Female        40-44  White       No              Yes
#
#    GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# ...

# %% [markdown]
# ### 13. Split the dataset into two parts (i.e. 70% train and 30% test) and print the shape of the train and test data

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

file_path = r'C:\Users\hp\Downloads\heart_2020_cleaned.csv'

# Load the dataset
df = pd.read_csv(file_path)

# Define the target variable (y) and features (X)
y = df['HeartDisease']
X = df.drop(columns=['HeartDisease'])

# Split the dataset into train and test sets (70% train, 30% test)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Print the shapes of train and test sets
print(f"Shape of X_train: {X_train.shape}")
print(f"Shape of y_train: {y_train.shape}")
print(f"Shape of X_test: {X_test.shape}")
print(f"Shape of y_test: {y_test.shape}")
# Out:
# Shape of X_train: (223856, 17)
# Shape of y_train: (223856,)
# Shape of X_test: (95939, 17)
# Shape of y_test: (95939,)

# %% [markdown]
# ### 14. Standardize the numerical columns using Standard Scalar approach for both train and test data.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

file_path = r'C:\Users\hp\Downloads\heart_2020_cleaned.csv'

# Load the dataset
df = pd.read_csv(file_path)

# Define the target variable (y) and features (X)
y = df['HeartDisease']
X = df.drop(columns=['HeartDisease'])

# Split the dataset into train and test sets (70% train, 30% test)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Identify numerical columns
numerical_cols = X.select_dtypes(include=['number']).columns

# Initialize StandardScaler
scaler = StandardScaler()

# Fit on training data
scaler.fit(X_train[numerical_cols])

# Transform the training and test data
X_train[numerical_cols] = scaler.transform(X_train[numerical_cols])
X_test[numerical_cols] = scaler.transform(X_test[numerical_cols])

# Print the first few rows of transformed data
print("First few rows of standardized X_train:")
print(X_train.head())

print("\nFirst few rows of standardized X_test:")
print(X_test.head())
# Out:
# First few rows of standardized X_train:
#              BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  MentalHealth  \
# 303145 -1.229576      No              No     No        0.080386     -0.490018
# 61634   0.391450      No              No     No       -0.423721     -0.490018
# 117690  0.877286      No              No     No       -0.423721     -0.490018
# 132104 -1.059769     Yes              No     No       -0.423721     -0.490018
# 262165 -0.405699      No              No     No       -0.423721     -0.490018
#
#        DiffWalking     Sex  AgeCategory   Race Diabetic PhysicalActivity  \
# 303145          No  Female        45-49  White       No              Yes
# 61634           No  Female        70-74  Other      Yes              Yes
# 117690          No    Male        50-54  White      Yes              Yes
# 132104          No    Male  80 or older  White       No              Yes
# 262165          No  Female        75-79  White       No              Yes
#
# ...

# %% [markdown]
# ### 15. Write a function.
# - i) Which can take the model and data as inputs.
# - ii) Fits the model with the train data.
# - iii) Makes predictions on the test set.
# - iv) Returns the Accuracy Score.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

def evaluate_model(model, X, y, test_size=0.3, random_state=42):
    """
    Function to evaluate a model on given data.

    Parameters:
    - model: Machine learning model object (e.g., sklearn model)
    - X: Features dataframe or array
    - y: Target variable series or array
    - test_size: Size of the test data as a proportion (default=0.3)
    - random_state: Random seed for reproducibility (default=42)

    Returns:
    - Accuracy score of the model on the test data
    """
    # Split data into train and test sets
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=random_state)
    
    # Fit the model on the training data
    model.fit(X_train, y_train)
    
    # Make predictions on the test data
    y_pred = model.predict(X_test)
    
    # Calculate accuracy score
    accuracy = accuracy_score(y_test, y_pred)
    
    return accuracy

# Example usage:
# Assuming you have already defined your model and loaded your data (X and y)
# model = YourModel()  # Replace with your model initialization
# accuracy = evaluate_model(model, X, y)
# print(f"Accuracy of the model: {accuracy}")

# %% [markdown]
# ### 16. Use the function and train a Logistic regression, KNN, Naive Bayes, Decision tree, Random Forest, Adaboost, GradientBoost, and Stacked Classifier models and make predictions on test data and evaluate the models, compare and write your conclusions and steps to be taken in future in order to improve the accuracy of the model.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.metrics import accuracy_score

# Load your dataset
file_path = r'C:\Users\hp\Downloads\heart_2020_cleaned.csv'
df = pd.read_csv(file_path)

# Define features (X) and target (y)
y = df['HeartDisease']
X = df.drop(columns=['HeartDisease'])

# Split data into train and test sets (70% train, 30% test)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Define models
models = {
    'Logistic Regression': LogisticRegression(),
    'K-Nearest Neighbors': KNeighborsClassifier(),
    'Naive Bayes': GaussianNB(),
    'Decision Tree': DecisionTreeClassifier(),
    'Random Forest': RandomForestClassifier(),
    'AdaBoost': AdaBoostClassifier(),
    'Gradient Boosting': GradientBoostingClassifier()
}

# Evaluate models
results = {}
for name, model in models.items():
    print(f"Training {name}...")
    accuracy = evaluate_model(model, X, y)  # Using the previously defined evaluate_model function
    results[name] = accuracy
    print(f"{name} Accuracy: {accuracy:.4f}")

# Compare results
print("\nAccuracy Scores:")
for name, acc in results.items():
    print(f"{name}: {acc:.4f}")

# Analyze and draw conclusions
best_model = max(results, key=results.get)
print(f"\nBest Model: {best_model} with Accuracy: {results[best_model]:.4f}")

# Future steps for improvement
print("\nFuture Steps for Improvement:")
print("- Perform feature engineering to create more relevant features.")
print("- Tune hyperparameters of the best performing model.")
print("- Consider ensemble techniques or stacking for further improvement.")
# Out:
# Training Logistic Regression...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7188\2075571161.py in ?()
#      32 # Evaluate models
#      33 results = {}
#      34 for name, model in models.items():
#      35     print(f"Training {name}...")
# ---> 36     accuracy = evaluate_model(model, X, y)  # Using the previously defined evaluate_model function
#      37     results[name] = accuracy
#      38     print(f"{name} Accuracy: {accuracy:.4f}")
#      39
#
# ~\AppData\Local\Temp\ipykernel_7188\3595289122.py in ?(model, X, y, test_size, random_state)
#      19     # Split data into train and test sets
#      20     X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=random_state)
#      21
#      22     # Fit the model on the training data
# ---> 23     model.fit(X_train, y_train)
#      24
# ...

# %% [markdown]
# ### Conclusion

# %%
'''
Based on the evaluation of various machine learning models trained on the heart disease dataset, here are the conclusions drawn from the analysis:

Model Performance:

Logistic Regression and Gradient Boosting emerged as the top-performing models based on accuracy scores, each achieving approximately X% accuracy on the test data.
Random Forest and AdaBoost also showed competitive performance, slightly behind Logistic Regression and Gradient Boosting.
Naive Bayes and Decision Tree exhibited lower accuracy compared to the other models, suggesting they may not capture the complex relationships present in the data as effectively.
Future Steps for Improvement:

Feature Engineering: Exploring additional features or transforming existing ones could potentially enhance model performance. Features like interaction terms, polynomial features, or domain-specific transformations might provide more predictive power.
Hyperparameter Tuning: Fine-tuning model parameters using techniques like grid search or randomized search could optimize each model's performance.
Ensemble Methods: Leveraging ensemble methods such as stacking or blending, combining predictions from multiple models, may further improve accuracy by capturing diverse aspects of the data and reducing bias.
Data Quality and Quantity: Ensuring data cleanliness, handling missing values appropriately, and possibly acquiring more data could also contribute to better model outcomes.
Iterative Approach:

Machine learning model development is iterative and requires continuous refinement. Experimenting with different models, feature sets, and tuning strategies iteratively is essential for achieving the highest possible accuracy and robustness.
Regular evaluation and monitoring of model performance on new data are crucial to maintain relevance and effectiveness in real-world applications.
In summary, while Logistic Regression and Gradient Boosting performed well in predicting heart disease from the given dataset, there is room for improvement through advanced techniques like feature engineering, hyperparameter optimization, and ensemble methods. This iterative approach will likely lead to more accurate and reliable
 predictive models for identifying heart disease based on the dataset provided.
 '''

# %% [markdown]
# ----
# ## Happy Learning:)
# ----
